# %%
import pandas as pd

# %%
data = pd.read_csv('ifood_df.csv')
data
# Out:
#        Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0     58138.0        0         0       58       635         88
# 1     46344.0        1         1       38        11          1
# 2     71613.0        0         0       26       426         49
# 3     26646.0        1         0       26        11          4
# 4     58293.0        1         0       94       173         43
# ...       ...      ...       ...      ...       ...        ...
# 2200  61223.0        0         1       46       709         43
# 2201  64014.0        2         1       56       406          0
# 2202  56981.0        0         0       91       908         48
# 2203  69245.0        0         1        8       428         30
# 2204  52869.0        1         1       40        84          3
#
#       MntMeatProducts  MntFishProducts  MntSweetProducts  MntGoldProds  ...  \
# 0                 546              172                88            88  ...
# ...

# %%
Data_Description = pd.read_excel('iFood_Feature_Descriptions.xlsx')
Data_Description
# Out:
#                  Feature                                        Description
# 0                 Income                                  دخل الأسرة السنوي
# 1                Kidhome                       عدد الأطفال الصغار في المنزل
# 2               Teenhome                            عدد المراهقين في المنزل
# 3                Recency                      عدد الأيام منذ آخر عملية شراء
# 4               MntWines           المبلغ المصروف على النبيذ خلال آخر سنتين
# 5              MntFruits          المبلغ المصروف على الفواكه خلال آخر سنتين
# 6        MntMeatProducts           المبلغ المصروف على اللحوم خلال آخر سنتين
# 7        MntFishProducts          المبلغ المصروف على الأسماك خلال آخر سنتين
# 8       MntSweetProducts         المبلغ المصروف على الحلويات خلال آخر سنتين
# 9           MntGoldProds  المبلغ المصروف على المنتجات الذهبية خلال آخر س...
# 10     NumDealsPurchases                        عدد المشتريات التي تمت بخصم
# ...

# %%
Data_Columns = []
for i in Data_Description['Description']:
    Data_Columns.append(i)
print(Data_Columns)
# Out:
# ['دخل الأسرة السنوي', 'عدد الأطفال الصغار في المنزل', 'عدد المراهقين في المنزل', 'عدد الأيام منذ آخر عملية شراء', 'المبلغ المصروف على النبيذ خلال آخر سنتين', 'المبلغ المصروف على الفواكه خلال آخر سنتين', 'المبلغ المصروف على اللحوم خلال آخر سنتين', 'المبلغ المصروف على الأسماك خلال آخر سنتين', 'المبلغ المصروف على الحلويات خلال آخر سنتين', 'المبلغ المصروف على المنتجات الذهبية خلال آخر سنتين', 'عدد المشتريات التي تمت بخصم', 'عدد المرات التي اشترى فيها العميل من الموقع الإلكتروني', 'عدد المرات التي اشترى فيها العميل من الكتالوج', 'عدد المرات التي اشترى فيها العميل من المتجر مباشرة', 'عدد زيارات العميل للموقع الإلكتروني خلال الشهر الماضي', 'هل وافق العميل على الحملة الإعلانية رقم 3؟', 'هل وافق العميل على الحملة رقم 4؟', 'هل وافق العميل على الحملة رقم 5؟', 'هل وافق العميل على الحملة رقم 1؟', 'هل وافق العميل على الحملة رقم 2؟', 'هل قدّم العميل شكوى خلال آخر سنتين؟', 'تكلفة الاتصال (غالبًا قيمة ثابتة)', 'الإيرادات (قد تكون قيمة مرجعية أو رقم ثابت)', 'هل استجاب العميل للحملة الأخيرة؟', 'عمر الع
# ...

# %%
len(Data_Columns)
# Out:
# 39

# %%
data.columns = Data_Columns
data
# Out:
#       دخل الأسرة السنوي  عدد الأطفال الصغار في المنزل  \
# 0               58138.0                             0
# 1               46344.0                             1
# 2               71613.0                             0
# 3               26646.0                             1
# 4               58293.0                             1
# ...                 ...                           ...
# 2200            61223.0                             0
# 2201            64014.0                             2
# 2202            56981.0                             0
# 2203            69245.0                             0
# 2204            52869.0                             1
#
#       عدد المراهقين في المنزل  عدد الأيام منذ آخر عملية شراء  \
# 0                           0                             58
# 1                           1                             38
# 2                           0                             26
# 3                           0                             26
# ...

# %%
data.to_csv("ifood_new_data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2205 entries, 0 to 2204
# Data columns (total 39 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   دخل الأسرة السنوي                                         2205 non-null   float64
#  1   عدد الأطفال الصغار في المنزل                              2205 non-null   int64
#  2   عدد المراهقين في المنزل                                   2205 non-null   int64
#  3   عدد الأيام منذ آخر عملية شراء                             2205 non-null   int64
#  4   المبلغ المصروف على النبيذ خلال آخر سنتين                  2205 non-null   int64
#  5   المبلغ المصروف على الفواكه خلال آخر سنتين                 2205 non-null   int64
#  6   المبلغ المصروف على اللحوم خلال آخر سنتين                  2205 non-null   int64
#  7   المبلغ المصروف على الأسماك خلال آخر سنتين                 2205 non-null   int64
# ...

# %%
data.nunique()
# Out:
# Income                  1963
# Kidhome                    3
# Teenhome                   3
# Recency                  100
# MntWines                 775
# MntFruits                158
# MntMeatProducts          551
# MntFishProducts          182
# MntSweetProducts         176
# MntGoldProds             212
# NumDealsPurchases         15
# NumWebPurchases           15
# NumCatalogPurchases       13
# NumStorePurchases         14
# NumWebVisitsMonth         16
# AcceptedCmp3               2
# AcceptedCmp4               2
# AcceptedCmp5               2
# AcceptedCmp1               2
# AcceptedCmp2               2
# Complain                   2
# Z_CostContact              1
# Z_Revenue                  1
# Response                   2
# Age                       56
# Customer_Days            662
# marital_Divorced           2
# marital_Married            2
# marital_Single             2
# marital_Together           2
# marital_Widow              2
# education_2n Cycle         2
# ...

# %%
Customer_Days = []
for i in data['Customer_Days']:
    Customer_Days.append(i / 364.25)
Customer_Days  = pd.DataFrame(Customer_Days)
Customer_Days
# Out:
#              0
# 0     7.747426
# 1     6.237474
# 2     6.783802
# 3     6.308854
# 4     6.369252
# ...        ...
# 2200  6.973233
# 2201  5.979410
# 2202  6.352780
# 2203  6.355525
# 2204  7.634866
#
# [2205 rows x 1 columns]

# %%
list(data['AcceptedCmpOverall']).count(2)
# Out:
# 81
